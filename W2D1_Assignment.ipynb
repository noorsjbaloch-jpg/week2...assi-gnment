# %% [markdown]
# # Code to AI — Week 2, Day 1 (ASSIGNMENT)
# ## My Top 5 List 🏆
# **Homework notebook · complete before the next class**
#
# **Submission:** push this notebook to a GitHub repo and paste the repo link in the WhatsApp group.
#
# **This week's rules:**
# - ✅ Use `for item in collection:` loops
# - ❌ No `if`/`else`, no `while` (Week 3!)
#
# ---
# ### The task
# Tum apne kisi bhi pasandeeda topic ki **"Top 5" list** banao — e.g. top 5 movies, top 5 foods, top 5 cricketers, top 5 games. Phir us par kuch operations karo (neeche steps diye hain).

# %% [markdown]
# ## Step 1 — Make your Top 5 list
# Apni 5 cheezein ek list mein daalo aur poori list print karo.

# %%
# TODO: apni top 5 list banao
top5 = ["Vladimir putin","Rowan Atkinson","Warren Buffett","Cristiano Ronaldo","Michael Jackson"]   # e.g. ["Babar Azam", "Virat Kohli", ...]

print(top5)
# Out:
# ['Vladimir putin', 'Rowan Atkinson', 'Warren Buffett', 'Cristiano Ronaldo', 'Michael Jackson']

# %% [markdown]
# ## Step 2 — Show count
# List mein kitne items hain, print karo using `len()`.

# %%
# TODO: print how many items
len(top5)
# Out:
# 5

# %% [markdown]
# ## Step 3 — Print nicely with a loop ⭐
# `for` loop use karke har item ko apni line par print karo, aage ek dash (`-`) ke saath.
# Expected style:
# ```
# - item one
# - item two
# ...
# ```

# %%
# TODO: loop over top5 and print "- <item>" for each

# %% [markdown]
# ## Step 4 — First, last & sorted
# 1. Pehla item print karo (index 0)
# 2. Aakhri item print karo (index -1)
# 3. Poori list ko **sorted** form mein print karo (use `sorted()`)

# %%
# TODO: first item
print(top5[0])

# TODO: last item
print(top5[-1])

# TODO: sorted list
print(sorted(top5))
# Out:
# Vladimir putin
# Michael Jackson
# ['Cristiano Ronaldo', 'Michael Jackson', 'Rowan Atkinson', 'Vladimir putin', 'Warren Buffett']

# %% [markdown]
# ## Step 5 — Edit your list
# 1. Ek naya item `append()` se add karo (ab top 6 ho gaye 😄)
# 2. Koi ek item `remove()` se nikaalo
# 3. Final list print karo

# %%
# TODO: append one item

top5.append("Taylor swift")
# TODO: remove one item
del top5[2]  # removes "Warren Buffett"

# TODO: print final list
print(top5)
# Out:
# ['Vladimir putin', 'Rowan Atkinson', 'Cristiano Ronaldo', 'Michael Jackson', 'Taylor swift']

# %% [markdown]
# ## Step 6 — A tuple fact 🔒
# Apne baare mein ek **tuple** banao jo change na ho: `(your_name, your_city)`.
# Phir loop chala kar dono values print karo.

# %%
# TODO: make your info tuple
my_info = ("noorulain","jamshoro")
print(my_info)
# TODO: loop over it and print each value

# %% [markdown]
# ## 🌟 Bonus (optional)
# Do lists banao — `subjects` aur `marks` (same length).
# `subjects` ko sort karke print karo, aur `marks` list ka use karke har mark ko loop se print karo.
#
# *(Koi if/else nahi — sirf loops, sort, len.)*

# %%
subjects = ["Math", "English", "Science", "Urdu"]
marks = [85, 78, 92, 88]

# TODO: sorted subjects
sorted_subjects = sorted(subjects)
print(sorted_subjects)

# TODO: loop and print each mark
# Out:
# ['English', 'Math', 'Science', 'Urdu']

# %% [markdown]
# ## ✅ Submission checklist
# - [ ] Saare steps complete + cells run ho rahe hain (no red errors)
# - [ ] Notebook GitHub repo mein push kiya
# - [ ] Repo link WhatsApp group mein paste kiya
#
# Bohat khoob! Kal milte hain Dictionaries ke saath. 🚀
